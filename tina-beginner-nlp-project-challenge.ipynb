# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for filename in filenames:
#     print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import nltk
# nltk.download()
# dir(nltk.corpus)

# %% [markdown]
# ### This Notebook is based on Tina's youtube video there -> https://www.youtube.com/watch?v=kHOVWiZKpHM ("Youtube comments are wild!").Be sure to visit both her channel and Ken Jee's one also featured in the video as they both contains a lot of useful content for learners like me!
# ### Tina Huang: https://www.youtube.com/channel/UC2UXDak6o7rBm23k3Vv5dww
# ### Ken Jee : https://www.youtube.com/channel/UCiT9RITQ9PW6BhXK0y2jaeg
# ### The data files and tina's version of this project can be found on this github link: https://www.youtube.com/redirect?event=video_description&redir_token=QUFFLUhqbUpqQTBfeEZteERFd01tTmVuZUZXTmR5WnZuZ3xBQ3Jtc0trYUNBZC1Hclk2Ym1Ua1BjekJkYkt1Z3JLVEM2Qjl4MGVyX3U5MWNqZGhZaUNPT3p3a3dvU1NERHNqd2ViTHVZaGVuQ0IwT01oRGU5V3I1cEZyVlpib0IwVEFKRXoxQWxWNFVFREJlQVJ4N2ZNZHVyZw&q=https%3A%2F%2Fgithub.com%2Fhellotinah%2Fyoutube_sentiment_analysis%2F

# %%
#### Many thanks to the following Kaggler for his notebook, very useful for a NLP newbie like me :o)
#### https://www.kaggle.com/shahules/basic-eda-cleaning-and-glove#Data-Cleaning

# %%
import os
# os.system("../input/tina-beginner-nlp-challenge-project/tina_kenjee_comments_nlp_script.py")
# !pip install

# %%
# %run tina-kenjee-comments-nlp-script.ipynb
# Out:
# all done?!

# %%
test_func()
# Out:
# it works!! :o)

# %%
import seaborn as sn
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
# !pip install wordcloud

# %%
### Import Statements ###

# Graphs section


# Imports for wordcloud

# from subprocess import check_output
from wordcloud import WordCloud, STOPWORDS

# Python spellchecker
# !pip install pyspellchecker
# from spellchecker import SpellChecker
# import string
# Textblob -> Taken from tina's notebook mentioned above :o)
# !pip install TextBlob
from textblob import TextBlob
from textblob import Word


from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.corpus import StringCategoryCorpusReader
print('done')
# Out:
# done

# %%
# # read the files
data_tina = pd.read_csv('tinas_comments.csv')
data_kenjee = pd.read_csv('kens_comments.csv')
# data_tina_corr = pd.read_csv('TinaSpelled.csv')
# data_kenjee_corr = pd.read_csv('KenJeeSpelled.csv')

# %%
data_tina.describe(include='all')
# Out:
#         Unnamed: 0 comment                  comment_id  \
# count   513.000000     513                         513
# unique         NaN     511                         513
# top            NaN      🔥🔥  UgzmDkqW6c9Ezop5blt4AaABAg
# freq           NaN       2                           1
# mean    256.000000     NaN                         NaN
# std     148.234611     NaN                         NaN
# min       0.000000     NaN                         NaN
# 25%     128.000000     NaN                         NaN
# 50%     256.000000     NaN                         NaN
# 75%     384.000000     NaN                         NaN
# max     512.000000     NaN                         NaN
#
#                                                author_url author_name  \
# count                                                 513         513
# unique                                                289         289
# top     http://www.youtube.com/channel/UC2UXDak6o7rBm2...  Tina Huang
# ...

# %%
data_kenjee.describe(include='all')
# Out:
#          Unnamed: 0     comment                  comment_id  \
# count   5828.000000        5828                        5828
# unique          NaN        5769                        5828
# top             NaN  I like it!  Ugxp895GhvQ1RejPAH94AaABAg
# freq            NaN          12                           1
# mean    2913.500000         NaN                         NaN
# std     1682.543016         NaN                         NaN
# min        0.000000         NaN                         NaN
# 25%     1456.750000         NaN                         NaN
# 50%     2913.500000         NaN                         NaN
# 75%     4370.250000         NaN                         NaN
# max     5827.000000         NaN                         NaN
#
#                                                author_url author_name  \
# count                                                5828        5828
# unique                                               3635        3621
# ...

# %%
def remove_punctuation(text):
    return text.replace('[^\w\s]',"")

# %%
# TO ADD TO SCRIPT



def clean_lines(row):
    # Regex 'Mask' to filter out garbage characters and stuff
    regex = r"[^0-9a-zA-Z\']+"
    subst = " "
    row = re.sub(regex,subst,row,0)
    return row

# %%
data_kenjee_corr = data_kenjee
data_kenjee_corr['comment'] = data_kenjee['comment'].apply(clean_lines)
data_kenjee_corr['comment'][1]
# Out:
# 'I have a hard dilemma where I graduated while having a data analyst internship but wished I did a data scientist internship on top of it during college I am guessing that my best route should be to land a data analyst role and then work my way up to a data scientist position as I gain more domain and real world experience working with data working on more projects added on my portfolio '

# %%
data_tina_corr = data_tina
data_tina_corr['comment'] = data_tina_corr['comment'].apply(clean_lines)
data_tina_corr['comment']
# Out:
# 0      Big thumbs up Very clearly explained Really en...
# 1      0 53 This private method earn 5000 in 2 days h...
# 2      Really thank you for this interview and I have...
# 3      They've changed the table so now your way is n...
# 4                 Is your first degree is really Doctor
#                              ...
# 508    I made this video completely on a whim and I'm...
# 509    Thank you so much for sharing your experience ...
# 510    You have literally answered my prayers Thank y...
# 511    Do you know if the online program has the same...
# 512    This was super useful Thanks for taking the ti...
# Name: comment, Length: 513, dtype: object

# %%
mrPolite = data_kenjee[data_kenjee['author_name']=='Muhammad Hashir']
mrPolite
# Out:
#       Unnamed: 0                                            comment  \
# 165          165  How do you reply too many comments all of them...
# 219          219  Congrats Ken You have achieved 100k victory su...
# 305          305  I think universitty of waterloo is best for ge...
# 306          306  How many internships you did and have you did ...
# 307          307  Fliping practice is nice Thanks for showing th...
# 308          308  We wanna see Ken starting a startup Let's give...
# 873          873  Ken you are really an expert on reviewing resumes
# 1468        1468  It's one of your best videos I really learned ...
# 1825        1825  Is competitive programming good for data scien...
# 2256        2256  You're growing so fast in terms of subscribers...
# 2263        2263  I hope next one will be ceo of nvidia haha but...
# 2275        2275  is BS a good degree fro landing a job in the f...
# 2292        2292  this hairstyle is also good but your previous ...
# ...

# %%
mrPolite['comment'].nunique()
# Out:
# 34

# %%
helloSirKenJee = data_kenjee_corr[data_kenjee_corr['comment'].str.contains('sir')]
ILikesayingSir = helloSirKenJee[['author_name','comment']].groupby('author_name').agg(np.count_nonzero)
ILikesayingSir.sort_values(by='comment',ascending=False)
# Out:
#                         comment
# author_name
# Muhammad Hashir              12
# IMPOSSIBLE THINGS             4
# Mr. Suraj Viswakarma          3
# Lori Zhuka                    3
# Harshita Chaurasia            3
# sagar mestry                  2
# karan mehta                   2
# Teju Teju                     1
# PRAMUDYA KAMAL JUMBLAT        1
# Pranay Pokala                 1
# Rahul Pawar                   1
# Ravi Bhat                     1
# Riz shah                      1
# Sachin Kumawat                1
# Senhor Radio                  1
# Shubham Thakur                1
# Tob Ias                       1
# Tirthabasi Sahoo              1
# Todd Moxley                   1
# Tony Omec                     1
# Vivek Patil                   1
# Yash Chaudhari                1
# adamgdev                      1
# ameer hamza                   1
# bhaskar subbaiah              1
# deepali lakdawala             1
# mohammad basheer              1
# rohith kumar                  1
# ...

# %%
# !python -m spacy download en_core_web_lg

import spacy
import random
from collections import Counter #for counting
import seaborn as sns #for visualization
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use('seaborn')
sns.set(font_scale=2)
import json
def pretty_print(pp_object):
    print(json.dumps(pp_object, indent=2))
    
from IPython.display import Markdown, display
def printmd(string, color=None):
    colorstr = "<span style='color:{}'>{}</span>".format(color, string)
    display(Markdown(colorstr))

# nlp = spacy.load('eng')
# Out:
# C:\Users\Pascal\anaconda3\lib\site-packages\cupy\_environment.py:213: UserWarning: CUDA path could not be detected. Set CUDA_PATH environment variable if CuPy fails to load.
#   warnings.warn(
# C:\Users\Pascal\anaconda3\lib\site-packages\cupy\_environment.py:213: UserWarning: CUDA path could not be detected. Set CUDA_PATH environment variable if CuPy fails to load.
#   warnings.warn(

# %%
# ?spacy.load££

# %%
def explain_text_entities(text):
    doc = nlp(text)
    for ent in doc.ents:
        print(f'Entity: {ent}, Label: {ent.label_}, {spacy.explain(ent.label_)}')

# %%
def concat_all_text(data,column):
    text = data[column].str.cat(sep=' ')

    # removing URLs and '&amp' substrings using regex
    import re
    url_reg  = r'[a-z]*[:.]+\S+'
    text   = re.sub(url_reg, '', text)
    noise_reg = r'\&amp'
    text   = re.sub(noise_reg, '', text)
#     regex = r"[^0-9a-zA-Z\']+"
    regex = r"[^a-zA-Z\']+"
    subst = " "
    text = re.sub(regex,subst,text,0)
    
    return text

KenJee_all_comments = concat_all_text(data_kenjee_corr,'comment')
KenJee_all_comments
# Out:
# "Kaggle recommended website for datasets learning data science I have a hard dilemma where I graduated while having a data analyst internship but wished I did a data scientist internship on top of it during college I am guessing that my best route should be to land a data analyst role and then work my way up to a data scientist position as I gain more domain and real world experience working with data working on more projects added on my portfolio Thank you for continuing to share and add to the community I started Kaggle and you make a lot of good points about the benefits for the short and long run with it Awesome tutorial I have a question Why do you log normalize Sibsp and Fare in addition to using StandardScaler What does the log normalization accomplish that the StandardScaler doesn't Let s be honest if your overall objective is to get a job why care about the school Just get the cheapest one and get it over with Any good data sets for a time series project Or anomaly detection
# ...

# %%
# pip install --user -U nltk

# %%
import nltk
# nltk.download()
from nltk.corpus import stopwords
my_stop = stopwords.words('english')
# type(stopwords)
data_kenjee_corr['clean_comments'] = data_kenjee_corr['comment'].str.lower()
data_kenjee_corr['clean_comments'] = data_kenjee_corr['clean_comments'].apply(lambda x: " ".join(x for x in x.split() if x not in my_stop))

data_kenjee_corr['clean_comments']
# Out:
# 0       kaggle recommended website datasets learning d...
# 1       hard dilemma graduated data analyst internship...
# 2       thank continuing share add community started k...
# 3       awesome tutorial question log normalize sibsp ...
# 4       let honest overall objective get job care scho...
#                               ...
# 5823    dear ken may know input data open high low clo...
# 5824    what's prediction ken 2018 least next 3 months...
# 5825                           nice nice models well make
# 5826            great video please post github link thank
# 5827    hi ken i've researching would really helpful c...
# Name: clean_comments, Length: 5828, dtype: object

# %%
import nltk

# %%
def get_stop_words(type="stopwordslib"):
    more_stopwords = set(['t','dtypes','n','dtype','v','wo','s','object'])
    if(type=="stopwordslib"):      
        from nltk.corpus import stopwords
        my_stop = stopwords.words('english')
#         my_stop = my_stop.union( more_stopwords)
    elif(type=="from_wordcloud"):
        my_stop =  set(STOPWORDS)
        my_stop = my_stop.union( more_stopwords)
    
    return my_stop

# %%
data_tina_corr = data_tina.copy()
my_stop = get_stop_words()
data_tina_corr['clean_comments'] = data_tina_corr['comment'].str.lower()
data_tina_corr['clean_comments'] = data_tina_corr['clean_comments'].apply(lambda x: " ".join(x for x in x.split() if x not in my_stop))

data_tina_corr['clean_comments']
# Out:
# 0      big thumbs clearly explained really enjoyed wo...
# 1      0 53 private method earn 5000 2 days https cod...
# 2      really thank interview questions 1 kind way te...
# 3      they've changed table way gonna work need get ...
# 4                             first degree really doctor
#                              ...
# 508    made video completely whim i'm glad helpful i'...
# 509    thank much sharing experience looking everywhe...
# 510    literally answered prayers thank courage enthu...
# 511         know online program opportunities campus one
# 512    super useful thanks taking time make video app...
# Name: clean_comments, Length: 513, dtype: object

# %%
data_kenjee_corr['clean_comments']
# Out:
# 0       kaggle recommended website datasets learning d...
# 1       hard dilemma graduated data analyst internship...
# 2       thank continuing share add community started k...
# 3       awesome tutorial question log normalize sibsp ...
# 4       let honest overall objective get job care scho...
#                               ...
# 5823    dear ken may know input data open high low clo...
# 5824    what's prediction ken 2018 least next 3 months...
# 5825                           nice nice models well make
# 5826            great video please post github link thank
# 5827    hi ken i've researching would really helpful c...
# Name: clean_comments, Length: 5828, dtype: object

# %%
#Import library
from textblob import Word


#Code for lemmatize
data_kenjee_corr['clean_comments'] = data_kenjee_corr['clean_comments'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
data_kenjee_corr['clean_comments']
# Out:
# 0       kaggle recommended website datasets learning d...
# 1       hard dilemma graduated data analyst internship...
# 2       thank continuing share add community started k...
# 3       awesome tutorial question log normalize sibsp ...
# 4       let honest overall objective get job care scho...
#                               ...
# 5823    dear ken may know input data open high low clo...
# 5824    what's prediction ken 2018 least next 3 month ...
# 5825                            nice nice model well make
# 5826            great video please post github link thank
# 5827    hi ken i've researching would really helpful c...
# Name: clean_comments, Length: 5828, dtype: object

# %%
#Code for lemmatize
data_tina_corr['clean_comments'] = data_tina_corr['clean_comments'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
data_tina_corr['clean_comments']
# Out:
# 0      big thumb clearly explained really enjoyed wou...
# 1      0 53 private method earn 5000 2 day http codz2...
# 2      really thank interview question 1 kind way tes...
# 3      they've changed table way gonna work need get ...
# 4                             first degree really doctor
#                              ...
# 508    made video completely whim i'm glad helpful i'...
# 509    thank much sharing experience looking everywhe...
# 510    literally answered prayer thank courage enthus...
# 511           know online program opportunity campus one
# 512    super useful thanks taking time make video app...
# Name: clean_comments, Length: 513, dtype: object

# %%
import nltk
print('yes')
# nltk.download()
# #Importing data

# from nltk.corpus import webtext
# nltk.download('webtext')
# wt_sentences = webtext.sents('firefox.txt')
# wt_words = webtext.words('firefox.txt')
# Out:
# yes

# %%
# ken_jee_sent = webtext.sents('kens_comments.csv')

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
def explain_text_entities(data,column):
    
    temp  = concat_all_text(data,column)
    doc = nlp(temp)
    entities = set()
    for ent in doc.ents:
        entities.add(ent)
#         entities.extend([{ent}, {ent.label_}, {spacy.explain(ent.label_)}])
#         entities.extend(f'Entity: {ent}, Label: {ent.label_}, {spacy.explain(ent.label_)}')
#         print(f'Entity: {ent}, Label: {ent.label_}, {spacy.explain(ent.label_)}')
    return entities
set_ent_kenjee = explain_text_entities(data_kenjee_corr,'clean_comments')
set_ent_kenjee
# data_kenjee['clean_comment'][:10].map(explain_text_entities,'comment
# Out:
# {english,
#  daily,
#  shud,
#  one,
#  one,
#  rmse random,
#  first,
#  sci kit info,
#  jim rohn,
#  one,
#  third,
#  next day,
#  first year,
#  kaggle,
#  first,
#  hourly,
#  one,
#  right year,
#  year old,
#  first,
#  zq klxx,
#  lwmfpu ab channel,
#  jpg title,
#  first,
#  last week,
#  october,
#  uxlnbdhmf w ab channel,
#  moana bc,
#  uxlnbdhmf w,
#  ecs,
#  maybe month,
#  second,
#  first,
#  niccolo anaconda lib,
#  english,
#  india,
#  year,
#  first,
#  ly mzwvkcy,
#  ab,
#  monica anaconda envs,
#  daily,
#  day day,
#  one,
#  ken month,
#  past month,
#  like week ago,
#  kate,
#  second,
#  one,
#  first,
#  summer,
#  roughly year,
#  second year,
#  third,
#  hudl past year,
#  one,
#  october,
#  gb ram,
#  four month ago,
#  one,
#  two,
#  month,
#  year,
#  huang,
#  two,
#  first,
#  one,
#  india,
#  year,
#  monica anaconda envs,
#  one,
#  john david's,
#  canada,
#  one,
#  month ago,
#  hugo,
#  one,
#  german,
#  awesome yoooo,
# ...

# %%
# dir(set_ent_kenjee)

# %%
dir(spacy)
# Out:
# ['Any',
#  'Config',
#  'Dict',
#  'Errors',
#  'Iterable',
#  'Language',
#  'Path',
#  'Union',
#  'Vocab',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'about',
#  'attrs',
#  'blank',
#  'cli',
#  'compat',
#  'displacy',
#  'errors',
#  'explain',
#  'git_info',
#  'glossary',
#  'info',
#  'kb',
#  'lang',
#  'language',
#  'lexeme',
#  'load',
#  'logger',
#  'lookups',
#  'matcher',
#  'ml',
#  'morphology',
#  'parts_of_speech',
#  'pipe_analysis',
#  'pipeline',
#  'prefer_gpu',
#  'registry',
#  'require_cpu',
#  'require_gpu',
#  'schemas',
#  'scorer',
#  'setup_default_warnings',
#  'strings',
#  'symbols',
#  'sys',
#  'tokenizer',
#  'tokens',
#  'training',
#  'util',
#  'vectors',
#  'vocab']

# %%
# ADD TO SCRIPT!!!

def processRow(row):
    
    temp = row.lower()
#     print(temp)
    temp = remove_emoji(temp)
    temp = remove_URL(temp)
    temp = remove_html(temp)
    temp = re.sub(r'[^\w\s]'," ",temp)
    
    # remove numbers
    temp = "".join([i for i in temp if not i.isdigit()])
    
    # Expand contraction ('im' -> 'i am' )
    temp = expand_contractions(temp)
    # Lemmatize & remove stopwords
    from nltk.corpus import stopwords
    my_stop = set(stopwords.words('english'))
    temp = " ".join([Word(word).lemmatize() for word in temp.split() if word not in my_stop if len(word)>1])
#     print([word for word in temp.split() if word not in my_stop])
#     print (temp)
    return temp


def get_fequencies(doc_column,column):
    doc_column = concat_all_text(doc_column,column)
    tokens = nltk.word_tokenize(doc_column)
    frequency_dist = nltk.FreqDist(tokens)

    import operator
    sorted_x = sorted(frequency_dist.items(), key=operator.itemgetter(1),reverse=True)
    sorted_x = sorted_x[:100]
    return sorted_x

# Sanity check for function above NOT to be put into script!
data_tina['clean_comment'] = data_tina['comment'].apply(processRow)
print(data_tina['clean_comment'][2])
print("")
print(data_tina['comment'][2])


feq_test = get_fequencies(data_tina,'clean_comment')
feq_test
# Out:
# really thank interview question kind way test generally master degree need write thesis credit graduate mcit course test general offline grad school write thesis level difficulty graduate think many people retire program want know real experience level graduate beginning easy afraid rapidly rising level degree whit offlines int coursera site say degree offlines want know apply company need reveal online degree
#
# ...

# %%
# Extract 
# !pip install gensim
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
import string
# Text preprocessing

# %%
data_tina.info(0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          513 non-null    int64
#  1   comment             513 non-null    object
#  2   comment_id          513 non-null    object
#  3   author_url          513 non-null    object
#  4   author_name         513 non-null    object
#  5   reply_count         513 non-null    int64
#  6   like_count          513 non-null    int64
#  7   date                513 non-null    object
#  8   vidid               513 non-null    object
#  9   total_reply_counts  513 non-null    int64
#  10  vid_title           513 non-null    object
#  11  just_date           513 non-null    object
#  12  clean_comment       513 non-null    object
# dtypes: int64(4), object(9)
# memory usage: 52.2+ KB

# %%
data_tina['total_reply_counts'].max()
# Out:
# 8

# %%
data_kenjee['total_reply_counts'].max()
# Out:
# 14

# %%
data_tina.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          513 non-null    int64
#  1   comment             513 non-null    object
#  2   comment_id          513 non-null    object
#  3   author_url          513 non-null    object
#  4   author_name         513 non-null    object
#  5   reply_count         513 non-null    int64
#  6   like_count          513 non-null    int64
#  7   date                513 non-null    object
#  8   vidid               513 non-null    object
#  9   total_reply_counts  513 non-null    int64
#  10  vid_title           513 non-null    object
#  11  just_date           513 non-null    object
#  12  clean_comment       513 non-null    object
# dtypes: int64(4), object(9)
# memory usage: 52.2+ KB

# %%
data_tina.vidid.count()
# Out:
# 513

# %%
data_kenjee.columns
# Out:
# Index(['Unnamed: 0', 'comment', 'comment_id', 'author_url', 'author_name',
#        'reply_count', 'like_count', 'date', 'vidid', 'total_reply_counts',
#        'vid_title', 'just_date', 'clean_comments'],
#       dtype='object')

# %%
data_kenjee['like_count'].sum()/len(data_kenjee)
# Out:
# 2.1535689773507207

# %%
print(len(data_kenjee))
print(data_kenjee['like_count'].sum())
# Out:
# 5828
# 12551

# %%
data_tina['like_count'].sum()/len(data_tina)
# Out:
# 0.645224171539961

# %%
len(data_kenjee)
# Out:
# 5828

# %%
# ?data_tina.duplicated()
# Out:
# Object `data_tina.duplicated()` not found.

# %%
# ?data_kenjee["comment"].duplicated
# Out:
# Object `data_kenjee["comment"].duplicated` not found.

# %%
data_kenjee_corr.to_csv("data_kenjee_corr.csv")

# %%
data_tina_corr.to_csv("data_tina_corr.csv")

# %%
data_tina_corr.head()
# Out:
#    Unnamed: 0                                            comment  \
# 0           0  Big thumbs up Very clearly explained Really en...
# 1           1  0 53 This private method earn 5000 in 2 days h...
# 2           2  Really thank you for this interview and I have...
# 3           3  They've changed the table so now your way is n...
# 4           4             Is your first degree is really Doctor
#
#                    comment_id  \
# 0  Ugx-FYMM1gPsoN3hw1B4AaABAg
# 1  Ugw7wRaJzx5-wH4-tt14AaABAg
# 2  Ugws1BT5twvi6Lh108R4AaABAg
# 3  Ugyz9y1UGg99d7y4Ko14AaABAg
# 4  Ugwh3sSSgcH__aMEqMF4AaABAg
#
#                                           author_url     author_name  \
# 0  http://www.youtube.com/channel/UCr4wD1q2l3_hQE...      mintao Wei
# 1  http://www.youtube.com/channel/UCEu06fgOkZxU2F...       Nike Nike
# 2  http://www.youtube.com/channel/UCk3sYdoFS53UHP...        heskeybi
# 3  http://www.youtube.com/channel/UCNP0onnHGAkmSR...  Chengzhu Zhang
# ...
